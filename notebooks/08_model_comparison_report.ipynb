# %% [markdown]
# # 08 Model Comparison Report
#
# Build a client-facing comparison table and plots from experiment metrics.

# %%
# !python scripts/compare_experiments.py

# %%
import pandas as pd
from pathlib import Path
p = Path('outputs/comparison/model_comparison.csv')
if p.exists():
    display(pd.read_csv(p))
else:
    print('No comparison file yet.')

# %% [markdown]
# Outputs include `model_comparison.csv`, Markdown/HTML summaries, best model JSON, mAP barplots, precision/recall scatter, per-class heatmap, and rare-class plot.
