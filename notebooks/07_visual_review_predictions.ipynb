# %% [markdown]
# # 07 Visual Review Predictions
#
# Create review galleries showing ground truth and predictions together.

# %%
EXPERIMENT = 'yolo8n_det'
for mode in ['mixed', 'high_confidence', 'low_confidence', 'false_positives', 'false_negatives', 'rare', 'crowded']:
    # !python scripts/visualize_predictions.py --experiment $EXPERIMENT --split test --n 50 --mode $mode

# %% [markdown]
# Outputs are written under `outputs/experiments/<experiment>/predictions/galleries/`. Green boxes are ground truth; red boxes are predictions.
